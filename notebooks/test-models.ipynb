# %%
import pandas as pd
import numpy as np
import tin_man_py as tm
from sklearn.metrics import mean_squared_error, mean_absolute_error
from common import data_split_train_test

PROPORTION_VALIDATION_DATASET = 0.3

df = pd.read_csv('../data/processed/processed_dataset.csv')
df.head()
# Out:
#    year  dewp  temp    pres   iws  is  ir  month_sin  month_cos  hour_sin  \
# 0  2010   -16  -4.0  1020.0  1.79   0   0        0.5   0.866025  0.000000
# 1  2010   -15  -4.0  1020.0  2.68   0   0        0.5   0.866025  0.258819
# 2  2010   -11  -5.0  1021.0  3.57   0   0        0.5   0.866025  0.500000
# 3  2010    -7  -5.0  1022.0  5.36   1   0        0.5   0.866025  0.707107
# 4  2010    -7  -5.0  1022.0  6.25   2   0        0.5   0.866025  0.866025
#
#    hour_cos  cbwd_NE  cbwd_NW  cbwd_SE  cbwd_cv  pm2_5
# 0  1.000000        0        0        1        0  129.0
# 1  0.965926        0        0        1        0  148.0
# 2  0.866025        0        0        1        0  159.0
# 3  0.707107        0        0        1        0  181.0
# 4  0.500000        0        0        1        0  138.0

# %%
train, test = data_split_train_test(df, PROPORTION_VALIDATION_DATASET)
